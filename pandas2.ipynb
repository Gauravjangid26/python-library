# %%
import pandas as pd

# %%
df=pd.read_csv("/Users/gauravjangid/Desktop/placemen1.csv")

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.describe() #statically view of data
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
top_left_corner_df=df.iloc[:4,:3] # iloc [row range,column range]
top_left_corner_df
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[1:3,['cgpa','placed']]  # loc[row range,column name]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
df.shape
# Out:
# (100, 3)

# %%
p=df.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b=df.empty # it return true if there are any missing data in dataframe
b
# Out:
# False

# %%
df.isnull().sum() # for checking missing values
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df.dropna()  # for removing missing row
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
i=df.ndim # return axes
i
# Out:
# 2

# %%
t=df.shape #rows,column
t
# Out:
# (100, 3)

# %%
d=df.size
d
# Out:
# 300

# %%
a=df.values  # get a numpy array for df
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df=df.copy()

# %%
p=df.sort_values(by="resume_score")
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
# type conversion
df["Cgpa"]=df["cgpa"].astype("int")
df
# Out:
#     cgpa  resume_score  placed  Cgpa
# 0   8.14          6.52       1     8
# 1   6.17          5.17       0     6
# 2   8.27          8.86       1     8
# 3   6.88          7.27       1     6
# 4   7.52          7.30       1     7
# ..   ...           ...     ...   ...
# 95  6.33          6.38       0     6
# 96  8.23          7.76       1     8
# 97  6.65          7.78       0     6
# 98  8.14          5.63       1     8
# 99  6.09          6.61       0     6
#
# [100 rows x 4 columns]

# %%
df=df.drop("Cgpa",axis=1)#df.drop(columns =["Cgpa"])
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
p=df.copy()

# %%
p["cgpa"]=p["cgpa"].astype(int)
p
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
p["resume_score"]=p["resume_score"].astype(int)
p
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      6             5       0
# 2      8             8       1
# 3      6             7       1
# 4      7             7       1
# ..   ...           ...     ...
# 95     6             6       0
# 96     8             7       1
# 97     6             7       0
# 98     8             5       1
# 99     6             6       0
#
# [100 rows x 3 columns]

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
# adding some data inn dataframe columns
df["cgpa"]=df["cgpa"].add(5)
df
# Out:
#      cgpa  resume_score  placed
# 0   13.14          6.52       1
# 1   11.17          5.17       0
# 2   13.27          8.86       1
# 3   11.88          7.27       1
# 4   12.52          7.30       1
# ..    ...           ...     ...
# 95  11.33          6.38       0
# 96  13.23          7.76       1
# 97  11.65          7.78       0
# 98  13.14          5.63       1
# 99  11.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df["resume_score"]=df["resume_score"].add(5)
df
# Out:
#      cgpa  resume_score  placed
# 0   13.14         16.52       1
# 1   11.17         15.17       0
# 2   13.27         18.86       1
# 3   11.88         17.27       1
# 4   12.52         17.30       1
# ..    ...           ...     ...
# 95  11.33         16.38       0
# 96  13.23         17.76       1
# 97  11.65         17.78       0
# 98  13.14         15.63       1
# 99  11.09         16.61       0
#
# [100 rows x 3 columns]

# %%
df["placed"]=df["placed"].add(5)
df
# Out:
#      cgpa  resume_score  placed
# 0   13.14         16.52       6
# 1   11.17         15.17       5
# 2   13.27         18.86       6
# 3   11.88         17.27       6
# 4   12.52         17.30       6
# ..    ...           ...     ...
# 95  11.33         16.38       5
# 96  13.23         17.76       6
# 97  11.65         17.78       5
# 98  13.14         15.63       6
# 99  11.09         16.61       5
#
# [100 rows x 3 columns]

# %%
df.add(1)
# Out:
#      cgpa  resume_score  placed
# 0   14.14         17.52       7
# 1   12.17         16.17       6
# 2   14.27         19.86       7
# 3   12.88         18.27       7
# 4   13.52         18.30       7
# ..    ...           ...     ...
# 95  12.33         17.38       6
# 96  14.23         18.76       7
# 97  12.65         18.78       6
# 98  14.14         16.63       7
# 99  12.09         17.61       6
#
# [100 rows x 3 columns]

# %%
#ek saath nikalna ho df.describe
df.count()
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
df.max()
# Out:
# cgpa            14.40
# resume_score    19.06
# placed           6.00
# dtype: float64

# %%
df.min()
# Out:
# cgpa            10.27
# resume_score    14.95
# placed           5.00
# dtype: float64

# %%
df.std()
# Out:
# cgpa            1.119200
# resume_score    0.979608
# placed          0.502519
# dtype: float64

# %%
df['cgpa'].mean()
# Out:
# 11.942200000000003

# %%
df['cgpa'].median()
# Out:
# 11.620000000000001

# %%
# filter method
#1.using filter function
df.filter(items=["cgpa","placed"])
# Out:
#      cgpa  placed
# 0   13.14       6
# 1   11.17       5
# 2   13.27       6
# 3   11.88       6
# 4   12.52       6
# ..    ...     ...
# 95  11.33       5
# 96  13.23       6
# 97  11.65       5
# 98  13.14       6
# 99  11.09       5
#
# [100 rows x 2 columns]

# %%
#2.using nested slicing
df[["cgpa","placed"]]
# Out:
#      cgpa  placed
# 0   13.14       6
# 1   11.17       5
# 2   13.27       6
# 3   11.88       6
# 4   12.52       6
# ..    ...     ...
# 95  11.33       5
# 96  13.23       6
# 97  11.65       5
# 98  13.14       6
# 99  11.09       5
#
# [100 rows x 2 columns]

# %%
df.filter(items=[3,4,5,6],axis=0)  # row wise operation
# Out:
#     cgpa  resume_score  placed
# 3  11.88         17.27       6
# 4  12.52         17.30       6
# 5  13.77         16.19       6
# 6  10.34         17.09       5

# %%
df[:3]
# Out:
#     cgpa  resume_score  placed
# 0  13.14         16.52       6
# 1  11.17         15.17       5
# 2  13.27         18.86       6

# %%
df.rename(columns={"cgpa": "updated_cgpa", "resume_score": "updated_resume_score"})
# Out:
#     updated_cgpa  updated_resume_score  placed
# 0          13.14                 16.52       6
# 1          11.17                 15.17       5
# 2          13.27                 18.86       6
# 3          11.88                 17.27       6
# 4          12.52                 17.30       6
# ..           ...                   ...     ...
# 95         11.33                 16.38       5
# 96         13.23                 17.76       6
# 97         11.65                 17.78       5
# 98         13.14                 15.63       6
# 99         11.09                 16.61       5
#
# [100 rows x 3 columns]

# %%
df.rename(index={0:1})
# Out:
#      cgpa  resume_score  placed
# 1   13.14         16.52       6
# 1   11.17         15.17       5
# 2   13.27         18.86       6
# 3   11.88         17.27       6
# 4   12.52         17.30       6
# ..    ...           ...     ...
# 95  11.33         16.38       5
# 96  13.23         17.76       6
# 97  11.65         17.78       5
# 98  13.14         15.63       6
# 99  11.09         16.61       5
#
# [100 rows x 3 columns]

# %%
# condition based filter
df.where(df["cgpa"]>7,other=0)
# Out:
#      cgpa  resume_score  placed
# 0   13.14         16.52       6
# 1   11.17         15.17       5
# 2   13.27         18.86       6
# 3   11.88         17.27       6
# 4   12.52         17.30       6
# ..    ...           ...     ...
# 95  11.33         16.38       5
# 96  13.23         17.76       6
# 97  11.65         17.78       5
# 98  13.14         15.63       6
# 99  11.09         16.61       5
#
# [100 rows x 3 columns]
